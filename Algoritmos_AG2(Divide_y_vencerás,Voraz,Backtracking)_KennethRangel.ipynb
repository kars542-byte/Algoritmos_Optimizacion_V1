# %% [markdown]
# <a href="https://colab.research.google.com/github/kars542-byte/Algoritmos_Optimizacion_V1/blob/main/Algoritmos_AG2(Divide_y_vencer%C3%A1s%2CVoraz%2CBacktracking)_Plantilla(no_borrar).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Actividad Guiada 1 de Algoritmos de Optimizacion
#
#
# Nombre: Kenneth Rangel
#
# https://colab.research.google.com/github/kars542-byte/Algoritmos_Optimizacion_V1/blob/main/Algoritmos_AG2(Divide_y_vencer%C3%A1s%2CVoraz%2CBacktracking)_KennethRangel.ipynb
#
# https://github.com/kars542-byte/Algoritmos_Optimizacion_V1/blob/77a999be4492f18ca306d63d9c5e4c448f3d8e7f/Algoritmos_AG2(Divide_y_vencer%C3%A1s%2CVoraz%2CBacktracking)_KennethRangel.ipynb
#
# 1.   Elemento de lista
# 2.   Elemento de lista

# %% [markdown]
# #Torres de Hanoi - Divide y venceras
# ![Captura de pantalla_2025-01-10_13-01-51.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla_2025-01-13_18-25-01.png](data:image/png;base64,...)

# %%
#Torres de Hanoi - Divide y venceras
################################################################################
import time
import matplotlib.pyplot as plt

################################################################
def Torres_Hanoi(N, desde, hasta):
  #N - Nº de fichas
  #desde - torre inicial
  #hasta - torre fina
  if N==1 :
    print("Lleva la ficha desde " + str(desde) + " hasta " + str(hasta))

  else:
    Torres_Hanoi(N-1, desde, 6-desde-hasta)
    print("Lleva la ficha desde " + str(desde) + " hasta " + str(hasta))
    Torres_Hanoi(N-1, 6-desde-hasta,  hasta)
comparador = [0,1,2]
start = time.time()
Torres_Hanoi(4, 2, 3)
end = time.time()
comparador[0] = round((end-start),5)
start = time.time()
Torres_Hanoi(8, 1, 2)
end = time.time()
comparador[1] = round((end-start),5)
start = time.time()
Torres_Hanoi(10, 3, 2)
end = time.time()
comparador[2] = round((end-start),5)
################################################################
plt.plot([4,8,10], comparador, 'ro-')
plt.xlabel('Cantidad de discos')
plt.ylabel('Tiempo (s)')
plt.title('Tiempo de ejecucion')
plt.grid(True)
plt.show()
# Out:
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 2 hasta 3
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 3 hasta 1
# Lleva la ficha desde 2 hasta 1
# Lleva la ficha desde 3 hasta 2
# Lleva la ficha desde 1 hasta 3
# Lleva la ficha desde 1 hasta 2
# Lleva la ficha desde 3 hasta 2
# ...

# %% [markdown]
# #Cambio de monedas - Técnica voraz

# %%
#Cambio de monedas - Técnica voraz
################################################################################
SISTEMA = [11, 5 ,1  ]
SISTEMA2 = [1000, 100, 50, 10, 1]
SISTEMA3 = [10000, 5000, 2000, 1000, 100, 500, 200, 100, 50, 20, 10, 5, 2, 1]
################################################################
def cambio_monedas(CANTIDAD,SISTEMA):
#....
  SOLUCION = [0]*len(SISTEMA)
  ValorAcumulado = 0

  for i,valor in enumerate(SISTEMA):
    monedas = (CANTIDAD-ValorAcumulado)//valor
    SOLUCION[i] = monedas
    ValorAcumulado = ValorAcumulado + monedas*valor

    if CANTIDAD == ValorAcumulado:
      return SOLUCION

  print("No es posible encontrar solucion")

comparador = [0,1,2]
start = time.time()
print(cambio_monedas(15,SISTEMA))
end = time.time()
comparador[0] = round((end-start),5)
start = time.time()
print(cambio_monedas(2569,SISTEMA2))
end = time.time()
comparador[1] = round((end-start),5)
start = time.time()
print(cambio_monedas(256065,SISTEMA3))
end = time.time()
comparador[2] = round((end-start),5)
################################################################
plt.plot([3,5,10], comparador, 'ro-')
plt.xlabel('Cantidad de discos')
plt.ylabel('Tiempo (s)')
plt.title('Tiempo de ejecucion')
plt.grid(True)
plt.show()
# Out:
# [1, 0, 4]
# [2, 5, 1, 1, 9]
# [25, 1, 0, 1, 0, 0, 0, 0, 1, 0, 1, 1, 0, 0]

# %% [markdown]
# #N Reinas - Vuelta Atrás(Backtracking)
# ![Captura de pantalla_2025-01-10_13-02-51.png](data:image/png;base64,...)

# %%
#N Reinas - Vuelta Atrás()
################################################################################

#Verifica que en la solución parcial no hay amenzas entre reinas
################################################################
def es_prometedora(SOLUCION,etapa):
################################################################
  #print(SOLUCION)
  #Si la solución tiene dos valores iguales no es valida => Dos reinas en la misma fila
  for i in range(etapa+1):
    #print("El valor " + str(SOLUCION[i]) + " está " +  str(SOLUCION.count(SOLUCION[i])) + " veces")
    if SOLUCION.count(SOLUCION[i]) > 1:
      return False

    #Verifica las diagonales
    for j in range(i+1, etapa +1 ):
      #print("Comprobando diagonal de " + str(i) + " y " + str(j))
      if abs(i-j) == abs(SOLUCION[i]-SOLUCION[j]) : return False
  return True

#Traduce la solución al tablero
################################################################
def escribe_solucion(S):
################################################################
  n = len(S)
  for x in range(n):
    print("")
    for i in range(n):
      if S[i] == x+1:
        print(" X " , end="")
      else:
        print(" - ", end="")



#Proceso principal de N-Reinas
################################################################
def reinas(N, solucion=[],etapa=0):
################################################################
### ....
  if len(solucion) == 0:         # [0,0,0...]
    solucion = [0 for i in range(N) ]

  for i in range(1, N+1):
    solucion[etapa] = i
    if es_prometedora(solucion, etapa):
      if etapa == N-1:
        print(solucion)
      else:
        reinas(N, solucion, etapa+1)
    else:
      None

  solucion[etapa] = 0

comparador = [0,1,2]
start = time.time()
reinas(5,solucion=[],etapa=0)
end = time.time()
comparador[0] = round((end-start),5)
start = time.time()
reinas(7,solucion=[],etapa=0)
end = time.time()
comparador[1] = round((end-start),5)
start = time.time()
reinas(10,solucion=[],etapa=0)
end = time.time()
comparador[2] = round((end-start),5)
################################################################
plt.plot([5,7,10], comparador, 'ro-')
plt.xlabel('Cantidad de discos')
plt.ylabel('Tiempo (s)')
plt.title('Tiempo de ejecucion')
plt.grid(True)
plt.show()
# Out:
# [1, 3, 5, 2, 4]
# [1, 4, 2, 5, 3]
# [2, 4, 1, 3, 5]
# [2, 5, 3, 1, 4]
# [3, 1, 4, 2, 5]
# [3, 5, 2, 4, 1]
# [4, 1, 3, 5, 2]
# [4, 2, 5, 3, 1]
# [5, 2, 4, 1, 3]
# [5, 3, 1, 4, 2]
# [1, 3, 5, 7, 2, 4, 6]
# [1, 4, 7, 3, 6, 2, 5]
# [1, 5, 2, 6, 3, 7, 4]
# [1, 6, 4, 2, 7, 5, 3]
# [2, 4, 1, 7, 5, 3, 6]
# [2, 4, 6, 1, 3, 5, 7]
# [2, 5, 1, 4, 7, 3, 6]
# [2, 5, 3, 1, 7, 4, 6]
# [2, 5, 7, 4, 1, 3, 6]
# [2, 6, 3, 7, 4, 1, 5]
# [2, 7, 5, 3, 1, 6, 4]
# [3, 1, 6, 2, 5, 7, 4]
# [3, 1, 6, 4, 2, 7, 5]
# [3, 5, 7, 2, 4, 6, 1]
# [3, 6, 2, 5, 1, 4, 7]
# [3, 7, 2, 4, 6, 1, 5]
# [3, 7, 4, 1, 5, 2, 6]
# [4, 1, 3, 6, 2, 7, 5]
# [4, 1, 5, 2, 6, 3, 7]
# [4, 2, 7, 5, 3, 1, 6]
# [4, 6, 1, 3, 5, 7, 2]
# [4, 7, 3, 6, 2, 5, 1]
# [4, 7, 5, 2, 6, 1, 3]
# [5, 1, 4, 7, 3, 6, 2]
# [5, 1, 6, 4, 2, 7, 3]
# [5, 2, 6, 3, 7, 4, 1]
# [5, 3, 1, 6, 4, 2, 7]
# [5, 7, 2, 4, 6, 1, 3]
# [5, 7, 2, 6, 3, 1, 4]
# [6, 1, 3, 5, 7, 2, 4]
# [6, 2, 5, 1, 4, 7, 3]
# [6, 3, 1, 4, 7, 5, 2]
# [6, 3, 5, 7, 1, 4, 2]
# [6, 3, 7, 4, 1, 5, 2]
# ...

# %%
escribe_solucion([1, 5, 8, 6, 3, 7, 2, 4])
# Out:
#  X  -  -  -  -  -  -  -
#  -  -  -  -  -  -  X  -
#  -  -  -  -  X  -  -  -
#  -  -  -  -  -  -  -  X
#  -  X  -  -  -  -  -  -
#  -  -  -  X  -  -  -  -
#  -  -  -  -  -  X  -  -
#  -  -  X  -  -  -  -  -
